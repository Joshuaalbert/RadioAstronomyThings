# %%
from Geometry import *
import numpy as np

def getAllDecendants(octTree):
    '''Get all lowest chilren on tree.'''
    out = []
    if octTree.hasChildren:
        for child in octTree.children:
            out = out + getAllDecendants(child)
        return out
    else:
        return [octTree]
    
def generateModelFromOctree(octTree,numRays,propName='Ne'):
    '''Generate '''
    voxels = getAllDecendants(octTree)        
    N = len(voxels)
    G = np.zeros([numRays,N])
    m = np.zeros(N)
    Cm = np.zeros(N)
    x = np.zeros([N,3])
    if propName not in voxels[0].properties.keys():
        #zero model if no property
        i = 0
        while i < N:
            vox = voxels[i]
            for j in vox.lineSegments.keys():
                G[j,i] = vox.lineSegments[j].sep   
            x[i,:] = vox.centroid
            i += 1
        return G,Cm,m,x
    i = 0
    while i < N:
        vox = voxels[i]
        for j in vox.lineSegments.keys():
            G[j,i] = vox.lineSegments[j].sep   
        m[i] = vox.properties[propName][1]
        Cm[i] = vox.properties[propName][2]
        x[i,:] = vox.centroid
        i += 1
    return G,Cm,m,x
        
def setOctTreeModel(octTree,m,Cm,propName='Ne',propType='extensive'):
    '''Set the model in the octTree. 
    Assumes the model is derived from the same octTree and
    Cm is the diagonal of the covariance.'''
    voxels = getAllDecendants(octTree)
    N = len(voxels)
    i = 0
    while i < N:
        vox = voxels[i]
        vox.properties[propName] = [propType,m[i],Cm[i]]
        vox.lineSegments = {}
        i += 1
    
def forwardProblem(rays,octTree):
    '''Perform the forward problem.'''
    
    pass
    
def noRefractionTECInversion(antennaLocs,antennaTEC, sourcePos):
    '''Invert the 3d TEC based on total measurments on the ground (after factor)
    antennaLocs are in uvw coords of shape
    antennaTEC are NxM'''
    pass

def makeRaysFromSourceAndReciever(recievers,sources):
    rays = []
    count = 0
    for r in recievers:
        for s in sources:
            rays.append(LineSegment(r,s,id=count))
            count += 1
    return rays

def LinearSolution(dobs,G,Cd,Cmprior,mprior):
    #forward problem
    print("Doing forward problem")
    d = G.dot(mprior)
    print("Calculating residuals:")
    residuals = dobs - d
    print(residuals)
    Gt = G.transpose()
    #smooth and adjoint
    print("Calculating smoothing matrix")
    smooth = np.linalg.inv(G.dot(Cmprior).dot(Gt) + Cd)
    print("Calculating adjoint")
    adjoint = Cmprior.dot(Gt).dot(smooth)
    print("updating model")
    m = mprior + adjoint.dot(residuals)
    print("updating covariance")
    Cm = Cmprior - adjoint.dot(G).dot(Cmprior)
    return m,Cm  



    
def compute3dExponentialCovariance(sigma2,L,x):
    N = x.shape[0]
    C = np.zeros([N,N])
    i = 0
    while i < N:
        C[i,i] = sigma2
        j = i+1
        while j < N:
            d = x[i,:] - x[j,:]
            C[i,j] = sigma2*np.exp(-np.linalg.norm(d)/L)
            C[j,i] = C[i,j]
            j += 1
        i += 1
    C[C<epsFloat] = 0.
    return C

def ExampleLinearSolution():
    levels = 3
    fileName = "octTree_{0}levels.npy".format(levels)
    baseWidth = 1.
    height = 1000.
    try:
        octTree = loadOctTree(fileName)
        G,Cm,m,x = generateModelFromOctree(octTree,0,propName='Ne')
    except:
        octTree = OctTree([0,0,height/2.],dx=baseWidth,dy=baseWidth,dz=height)
        subDivideToDepth(octTree,levels)
        saveOctTree(fileName,octTree)
        G,Cm,m,x = generateModelFromOctree(octTree,0,propName='Ne')
        
    
    mexact = np.zeros_like(m)
    M = 2
    print("Generating {0} component model".format(M))
    for i in range(M):
        loc = np.array([np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = height/2.,high = height)])
        mexact += 0.3 + np.random.uniform()*np.exp(-np.sum((x - loc)**2,axis=1)/(height/8.)**2)
    modelVar = 0.1
    print("Computing model 3d exponential covariance")
    Cmexact = compute3dExponentialCovariance(modelVar,baseWidth/2.,x)
    print("Setting octTree with model.")
    setOctTreeModel(octTree,mexact,np.diag(Cmexact),propName='Ne',propType='extensive')
    M = 5
    print("Generating {0} recievers".format(M))
    recievers = []
    for i in range(M):
        recievers.append([np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               -epsFloat])
    M = 10
    print("Generating {0} sources".format(M))
    sources = []
    for i in range(M):
        sources.append([np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               height])
    rays = makeRaysFromSourceAndReciever(recievers,sources)
    print("Propagating {0} rays".format(len(rays)))
    for ray in rays:
        forwardRay(ray,octTree)
    print("Pulling ray propagations.")
    G,CmVar,mexact,x = generateModelFromOctree(octTree,len(rays),propName='Ne')
    
    #generate model
    print("Computing fake observations")
    dobs = []
    for i in range(20):
        dobs.append(G.dot(np.random.multivariate_normal(mean=mexact, cov = Cmexact)))
        #print(dobs[-1])
    dobs = np.array(dobs)
    Cd = np.cov(dobs.transpose())
    dobs = np.mean(dobs,axis=0)
    #print (dobs)
    mprior = mexact/0.5
    print("Solving for model from rays:")
    print("solution with Cm exact input")
    m,Cm = LinearSolution(dobs,G,Cd,Cmexact,mprior)
    import pylab as plt
    plt.plot(m,label='res')
    plt.plot(mexact,label='ex')
    plt.plot(mprior,label='pri')
    plt.legend(frameon=False)
    plt.show()
    plotOctTreeXZ(octTree,ax=None)
    plotOctTree3D(octTree,model=m)
    f,(ax1,ax2) = plt.subplots(2,1,sharex=True,sharey=True)
    ax1.imshow(Cm)
    ax2.imshow(Cmexact)
    plt.show()
    print("solution with Cm diagonal")
    m,Cm = LinearSolution(dobs,G,Cd,np.diag(np.diag(Cmexact)),mprior)
    import pylab as plt
    plt.plot(m,label='res')
    plt.plot(mexact,label='ex')
    plt.plot(mprior,label='pri')
    plt.legend(frameon=False)
    plt.show()
    plotOctTreeXZ(octTree,ax=None)
    plotOctTree3D(octTree,model=m)
    f,(ax1,ax2) = plt.subplots(2,1,sharex=True,sharey=True)
    ax1.imshow(Cm)
    ax2.imshow(Cmexact)
    plt.show()
    
def SteepestDescent(octTree,rays,dobs,Cd,Cmprior,mprior):
    iter = 0
    mn = mprior
    while iter < 100:
        #forward problem
        print("Setting octTree with model_{0}".format(iter))
        setOctTreeModel(octTree,mn,np.diag(Cmprior),propName='Ne',propType='extensive')
        print("Propagating {0} rays".format(len(rays)))
        for ray in rays:
            forwardRay(ray,octTree)
        print("Pulling ray propagations.")
        G,CmVar,mexact,x = generateModelFromOctree(octTree,len(rays),propName='Ne')
        print("Doing forward problem")
        d = G.dot(mn)
        print("Calculating residuals, Sum:")
        residuals = d - dobs
        print(np.sum(residuals**2))
        print("Calculating weighting residuals")
        weightedRes = np.linalg.pinv(Cd).dot(residuals)
        #print(weightedRes,np.linalg.solve(Cd,residuals))
        #next part should be changed
        Gt = G.transpose()
        #smooth and adjoint
        print("Calculating adjoint")
        dm = Cmprior.dot(Gt).dot(weightedRes)
        print("updating model")
        mn = mn - 0.01*(dm + mn - mprior)
        iter += 1
    
    print("updating covariance")
    print("Calculating smoothing matrix")
    smooth = np.linalg.pinv(G.dot(Cmprior).dot(Gt) + Cd)
    print("Calculating adjoint")
    adjoint = Cmprior.dot(Gt).dot(smooth)
    Cm = Cmprior - adjoint.dot(G).dot(Cmprior)
    return mn,Cm  

def constructIonosphereModel(maxBaseline,):
    levels = 3
    fileName = "ionosphereModel_{0}levels.npy".format(levels)
    baseWidth = 1.
    height = 1000.#km
    try:
        octTree = loadOctTree(fileName)
        G,Cm,m,x = generateModelFromOctree(octTree,0,propName='Ne')
    except:
        octTree = OctTree([0,0,height/2.],dx=baseWidth,dy=baseWidth,dz=height)
        subDivideToDepth(octTree,levels)
        saveOctTree(fileName,octTree)
        G,Cm,m,x = generateModelFromOctree(octTree,0,propName='Ne')
    
    
if __name__=='__main__':
    #ExampleLinearSolution()
    levels = 3
    fileName = "octTree_{0}levels.npy".format(levels)
    baseWidth = 1.
    height = 1000.
    try:
        octTree = loadOctTree(fileName)
        G,Cm,m,x = generateModelFromOctree(octTree,0,propName='Ne')
    except:
        octTree = OctTree([0,0,height/2.],dx=baseWidth,dy=baseWidth,dz=height)
        subDivideToDepth(octTree,levels)
        saveOctTree(fileName,octTree)
        G,Cm,m,x = generateModelFromOctree(octTree,0,propName='Ne')
        
    
    mexact = np.zeros_like(m)
    M = 3
    print("Generating {0} component model".format(M))
    for i in range(M):
        loc = np.array([np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = height/2.,high = height)])
        mexact += 0.3 + np.random.uniform()*np.exp(-np.sum((x - loc)**2,axis=1)/(height/8.)**2)
    modelVar = 0.1
    print("Computing model 3d exponential covariance")
    Cmexact = compute3dExponentialCovariance(modelVar,baseWidth/2.,x)
    print("Setting octTree with model.")
    setOctTreeModel(octTree,mexact,np.diag(Cmexact),propName='Ne',propType='extensive')
    M = 10
    print("Generating {0} recievers".format(M))
    recievers = []
    for i in range(M):
        recievers.append([np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               -epsFloat])
    M = 10
    print("Generating {0} sources".format(M))
    sources = []
    for i in range(M):
        sources.append([np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               np.random.uniform(low = -baseWidth/2.,high = baseWidth/2.),
               height])
    rays = makeRaysFromSourceAndReciever(recievers,sources)
    print("Propagating {0} rays".format(len(rays)))
    for ray in rays:
        forwardRay(ray,octTree)
    print("Pulling ray propagations.")
    G,CmVar,mexact,x = generateModelFromOctree(octTree,len(rays),propName='Ne')
    
    #generate model
    print("Computing fake observations")
    dobs = []
    for i in range(20):
        dobs.append(G.dot(np.random.multivariate_normal(mean=mexact, cov = Cmexact)))
        #print(dobs[-1])
    dobs = np.array(dobs)
    Cd = np.cov(dobs.transpose())
    dobs = np.mean(dobs,axis=0)
    #print (dobs)
    mprior = mexact*0.5
    print("Solving for model from rays:")
    #m,Cm = LinearSolution(dobs,G,Cd,Cmexact,mprior)
    m,Cm = SteepestDescent(octTree,rays,dobs,Cd,Cmexact,mprior)
    CmCm = Cm.dot(np.linalg.inv(Cmexact))
    R = np.eye(CmCm.shape[0]) - CmCm
    print("Resolved by dataSet:{0}, resolved by a priori:{1}".format(np.trace(R),np.trace(CmCm)))
    import pylab as plt
    plt.plot(m,label='res')
    plt.plot(mexact,label='ex')
    plt.plot(mprior,label='pri')
    plt.legend(frameon=False)
    plt.show()
    plotOctTreeXZ(octTree,ax=None)
    plotOctTree3D(octTree,model=m)
# Out:
# Generating 3 component model
# Computing model 3d exponential covariance
# Setting octTree with model.
# Generating 10 recievers
# Generating 10 sources
# Propagating 100 rays
# Pulling ray propagations.
# Computing fake observations
# C:\Users\josh\WinPython-64bit-3.5.1.3\notebooks\RadioAstronomyThings\IonoTomo\IonoTomo\Geometry.py:113: RuntimeWarning: invalid value encountered in true_divide
#   self.dir = np.array(direction)/np.sqrt(np.dot(direction,direction))
# Solving for model from rays:
# Setting octTree with model_0
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 32613216.5828
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_1
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 31868206.7383
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_2
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 31150301.936
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_3
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 30458377.1144
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_4
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 29791358.7443
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_5
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 29148222.2977
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_6
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 28527989.8481
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_7
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 27929727.7933
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_8
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 27352544.6957
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_9
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 26795589.2334
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_10
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 26258048.256
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_11
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 25739144.9397
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_12
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 25238137.0361
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_13
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 24754315.2107
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_14
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 24287001.4652
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_15
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 23835547.6398
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_16
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 23399333.9911
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_17
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 22977767.8421
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_18
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 22570282.2996
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_19
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 22176335.0361
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_20
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 21795407.1333
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_21
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 21427001.9823
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_22
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 21070644.2394
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_23
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 20725878.834
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_24
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 20392270.0252
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_25
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 20069400.505
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_26
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 19756870.5469
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_27
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 19454297.1947
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_28
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 19161313.493
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_29
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 18877567.7541
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_30
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 18602722.8614
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_31
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 18336455.6065
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_32
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 18078456.0589
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_33
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 17828426.966
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_34
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 17586083.1821
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_35
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 17351151.1254
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_36
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 17123368.2607
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_37
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 16902482.6072
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_38
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 16688252.2696
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_39
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 16480444.9922
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_40
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 16278837.7337
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_41
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 16083216.2623
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_42
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 15893374.7701
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_43
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 15709115.5058
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_44
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 15530248.4246
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_45
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 15356590.8543
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_46
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 15187967.1776
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_47
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 15024208.5289
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_48
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 14865152.5052
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_49
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 14710642.8904
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_50
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 14560529.3927
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_51
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 14414667.3936
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_52
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 14272917.709
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_53
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 14135146.3609
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_54
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 14001224.3597
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_55
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13871027.4962
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_56
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13744436.1434
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_57
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13621335.0672
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_58
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13501613.2452
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_59
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13385163.6945
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_60
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13271883.3063
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_61
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13161672.6887
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_62
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 13054436.0158
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_63
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12950080.8844
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_64
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12848518.1759
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_65
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12749661.9253
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_66
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12653429.1955
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_67
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12559739.957
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_68
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12468516.9733
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_69
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12379685.6908
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_70
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12293174.1339
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_71
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12208912.8043
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_72
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12126834.5848
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_73
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 12046874.647
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_74
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11968970.3638
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_75
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11893061.224
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_76
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11819088.7525
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_77
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11746996.4321
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_78
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11676729.6299
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_79
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11608235.5261
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_80
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11541463.0456
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_81
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11476362.7934
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_82
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11412886.9918
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_83
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11350989.4204
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_84
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11290625.3586
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_85
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11231751.5309
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_86
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11174326.0535
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_87
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11118308.3843
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_88
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11063659.2735
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_89
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 11010340.7174
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_90
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10958315.9138
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_91
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10907549.2185
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_92
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10858006.1043
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_93
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10809653.1215
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_94
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10762457.8594
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_95
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10716388.9104
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_96
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10671415.8342
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_97
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10627509.1248
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_98
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10584640.1771
# Calculating weighting residuals
# Calculating adjoint
# updating model
# Setting octTree with model_99
# Propagating 100 rays
# Pulling ray propagations.
# Doing forward problem
# Calculating residuals, Sum:
# 10542781.2569
# Calculating weighting residuals
# Calculating adjoint
# updating model
# updating covariance
# Calculating smoothing matrix
# Calculating adjoint
# Resolved by dataSet:79.5982803548273, resolved by a priori:432.4017196451727

# %%
f,(ax1,ax2) = plt.subplots(2,1,sharex=True,sharey=True)
ax1.imshow(Cm)
ax2.imshow(Cmexact)
plt.show()

# %%
m,Cm = LinearSolution(dobs,G,Cd,Cmexact,mprior)
CmCm = Cm.dot(np.linalg.inv(Cmexact))
R = np.eye(CmCm.shape[0]) - CmCm
print("Resolved by dataSet:{0}, resolved by a priori:{1}".format(np.trace(R),np.trace(CmCm)))
import pylab as plt
plt.plot(m,label='res')
plt.plot(mexact,label='ex')
plt.plot(mprior,label='pri')
plt.legend(frameon=False)
plt.show()
# Out:
# Doing forward problem
# Calculating residuals:
# [ 620.73379001  612.43555718  625.04747154  625.55605035  609.69680274
#   618.18564228  647.67288382  636.20285667  627.2608913   627.2226498
#   621.48061263  592.98669616  613.24361466  620.85809097  631.14864159
#   614.8037199   619.63701376  625.77617391  626.25155257  598.69720273
#   630.00192243  619.57852847  601.930617    617.68291439  616.09457505
#   617.53253207  602.19013662  620.4429722   616.68904706  608.89894137
#   634.87338052  613.2963879   610.98232291  639.11835163  635.81070611
#   638.92145126  620.61570252  610.83829823  617.23463426  599.97924891
#   631.5696202   598.21381942  617.8253217   603.80898283  649.27659824
#   638.1479949   610.07843517  625.74916196  626.10866403  623.90838484
#   648.34009341  603.13666391  608.8346001   598.03984401  633.43091185
#   643.25921885  630.94527188  610.042684    614.44261171  632.29538341
#   634.00662519  631.37903375  611.30040633  608.6322505   627.93160079
#   624.71408711  637.92383139  624.54522543  629.7455966   628.53404795
#   602.55770051  573.68809885  597.20329586  596.19258585  607.96141787
#   616.94640549  594.0513976   572.88125816  586.22651841  615.69145013
#   622.07574473  609.64770475  640.83118757  637.39866625  611.10569416
#   637.05811402  653.02384113  623.81894118  622.74979907  643.63137212
#   582.44442936  576.97601073  583.77922398  577.64980702  594.14318408
#   587.10900177  574.14955019  576.16915111  588.52373478  608.77859975]
# Calculating smoothing matrix
# Calculating adjoint
# updating model
# updating covariance
# Resolved by dataSet:84.41145215199379, resolved by a priori:427.5885478480062
